# %% [markdown]
# # Dataset analytics for SRS

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# Read individual CSVs
df1 = pd.read_csv("C:/Users/Chloe/Documents/MaastrichtLaw&Tech/Thesis/MscThesis/Dataset/Metadata/2020_rs_data.csv")
df2 = pd.read_csv("C:/Users/Chloe/Documents/MaastrichtLaw&Tech/Thesis/MscThesis/Dataset/Metadata/2021_rs_data.csv")
df3 = pd.read_csv("C:/Users/Chloe/Documents/MaastrichtLaw&Tech/Thesis/MscThesis/Dataset/Metadata/2022_rs_data.csv")

# Concatenate dataframes vertically
combined = pd.concat([df1, df2, df3], ignore_index=True)

# %%
combined.head()
# Out:
#                     ecli        date  \
# 0    ECLI:NL:CBB:2020:10  2020-01-07
# 1   ECLI:NL:CBB:2020:100  2020-02-18
# 2  ECLI:NL:CBB:2020:1001  2020-12-22
# 3  ECLI:NL:CBB:2020:1002  2020-12-22
# 4  ECLI:NL:CBB:2020:1003  2020-12-22
#
#                                     inhoudsindicatie  \
# 0  \n\nArtikel 23, derde en zesde lid, van de Mes...
# 1  \nFosfaatrechten. Artikel 23, derde en zesde l...
# 2  \n\nFosfaatrechten. Knelgevallenregeling. Arti...
# 3  \nFosfaatrechten. Knelgevallenregeling. Artike...
# 4  \nFosfaatrechten. Knelgevallenregeling. Uit de...
#
#                                    instantie   rechtsgebied  wetsverwijzing  \
# 0  College van Beroep voor het bedrijfsleven  Bestuursrecht             NaN
# 1  College van Beroep voor het bedrijfsleven  Bestuursrecht             NaN
# 2  College van Beroep voor het bedrijfsleven  Bestuursrecht  Meststoffenwet
# 3  College van Beroep voor het bedrijfsleven  Bestuursrecht  Meststoffenwet
# 4  College van Beroep voor het bedrijfsleven  Bestuursrecht  Meststoffenwet
#
#                                        procesverloop  \
# 0  \nProcesverloop \n\n\nBij besluit van 3 januar...
# 1  \nProcesverloop \n\n\nBij besluit van 13 janua...
# 2  \nProcesverloop \n\n\nBij besluit van 10 janua...
# 3  \nProcesverloop \n\n\nBij besluit van 3 januar...
# 4  \nProcesverloop \n\n\nBij besluit van 10 janua...
#
#                                         overwegingen  \
# 0  \nOverwegingen \n\n\n1.1\n\nAppellante exploit...
# 1  \nOverwegingen \n\n\n\nRelevante bepalingen\n\...
# 2  \nOverwegingen \n\n\n\nRelevante bepalingen\n\...
# 3  \nOverwegingen \n\n\n\nRelevante bepalingen\n\...
# 4  \nOverwegingen \n\n\n\nRelevante bepalingen\n\...
#
#                                           beslissing
# 0  \nBeslissing\n\n\nHet College:\n\n\n\nverklaar...
# 1  \nBeslissing\n\n\nHet College:\n\n\n- verklaar...
# 2  \nBeslissing\n\n\nHet College\n\n- verklaart h...
# 3  \nBeslissing\n\n\nHet College verklaart het be...
# 4  \nBeslissing\n\n\nHet College:\n\n- verklaart ...

# %%
combined['year'] = pd.to_datetime(combined['date']).dt.year
combined.to_csv("C:/Users/Chloe/Documents/MaastrichtLaw&Tech/Thesis/MscThesis/Dataset/Metadata/combined.csv", index=False)
combined.head()
# Out:
#                     ecli        date  \
# 0    ECLI:NL:CBB:2020:10  2020-01-07
# 1   ECLI:NL:CBB:2020:100  2020-02-18
# 2  ECLI:NL:CBB:2020:1001  2020-12-22
# 3  ECLI:NL:CBB:2020:1002  2020-12-22
# 4  ECLI:NL:CBB:2020:1003  2020-12-22
#
#                                     inhoudsindicatie  \
# 0  \n\nArtikel 23, derde en zesde lid, van de Mes...
# 1  \nFosfaatrechten. Artikel 23, derde en zesde l...
# 2  \n\nFosfaatrechten. Knelgevallenregeling. Arti...
# 3  \nFosfaatrechten. Knelgevallenregeling. Artike...
# 4  \nFosfaatrechten. Knelgevallenregeling. Uit de...
#
#                                    instantie   rechtsgebied  wetsverwijzing  \
# 0  College van Beroep voor het bedrijfsleven  Bestuursrecht             NaN
# 1  College van Beroep voor het bedrijfsleven  Bestuursrecht             NaN
# 2  College van Beroep voor het bedrijfsleven  Bestuursrecht  Meststoffenwet
# 3  College van Beroep voor het bedrijfsleven  Bestuursrecht  Meststoffenwet
# 4  College van Beroep voor het bedrijfsleven  Bestuursrecht  Meststoffenwet
#
#                                        procesverloop  \
# 0  \nProcesverloop \n\n\nBij besluit van 3 januar...
# 1  \nProcesverloop \n\n\nBij besluit van 13 janua...
# 2  \nProcesverloop \n\n\nBij besluit van 10 janua...
# 3  \nProcesverloop \n\n\nBij besluit van 3 januar...
# 4  \nProcesverloop \n\n\nBij besluit van 10 janua...
#
#                                         overwegingen  \
# 0  \nOverwegingen \n\n\n1.1\n\nAppellante exploit...
# 1  \nOverwegingen \n\n\n\nRelevante bepalingen\n\...
# 2  \nOverwegingen \n\n\n\nRelevante bepalingen\n\...
# 3  \nOverwegingen \n\n\n\nRelevante bepalingen\n\...
# 4  \nOverwegingen \n\n\n\nRelevante bepalingen\n\...
#
#                                           beslissing    year
# 0  \nBeslissing\n\n\nHet College:\n\n\n\nverklaar...  2020.0
# 1  \nBeslissing\n\n\nHet College:\n\n\n- verklaar...  2020.0
# 2  \nBeslissing\n\n\nHet College\n\n- verklaart h...  2020.0
# 3  \nBeslissing\n\n\nHet College verklaart het be...  2020.0
# 4  \nBeslissing\n\n\nHet College:\n\n- verklaart ...  2020.0

# %%
# Group by 'year' and 'instantie', then count the occurrences
grouped = combined.groupby(['year', 'instantie']).size().reset_index(name='value')

# %%
# Get unique years and instanties
years = grouped['year'].unique()
instanties = grouped['instantie'].unique()

# %%
grouped
# Out:
#       year                                          instantie  value
# 0   2020.0                           Centrale Raad van Beroep   1008
# 1   2020.0          College van Beroep voor het bedrijfsleven    961
# 2   2020.0  Gemeenschappelijk Hof van Justitie van Aruba, ...     16
# 3   2020.0  Gerecht in Ambtenarenzaken van Aruba, Curaçao,...     44
# 4   2020.0                 Gerecht in Eerste Aanleg van Aruba     48
# ..     ...                                                ...    ...
# 71  2022.0                          Rechtbank Noord-Nederland    522
# 72  2022.0                             Rechtbank Oost-Brabant    191
# 73  2022.0                               Rechtbank Overijssel    212
# 74  2022.0                                Rechtbank Rotterdam   1229
# 75  2022.0                     Rechtbank Zeeland-West-Brabant   1540
#
# [76 rows x 3 columns]

# %%
# Create an empty dictionary to hold the base heights for each year
base_height = {year: 0 for year in years}

# Set the figure size
plt.figure(figsize=(10, 10))

# %%
# Loop through each 'instantie' and create the stacked bars
for instantie in instanties:
    # Get the subset of data for this 'instantie'
    subset = grouped[grouped['instantie'] == instantie]

    # Plot the bars for this 'instantie'
    plt.bar(
        subset['year'],
        subset['value'],
        bottom=[base_height[year] for year in subset['year']],
        label=instantie
    )

    # Update the base height for each year
    for i, row in subset.iterrows():
        base_height[row['year']] += row['value']

# %%
# Set labels and legend
plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Stacked Bar Graph with Matplotlib')
plt.legend(title='Instantie')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.savefig('Stats/stats_full_20_22.png')
plt.close()

# %%
grouped.to_csv("Stats/stats_full_20_22.csv", index=False)

# %% [markdown]
# # Create subset

# %%
sampling_ratio = 0.2

groups = grouped['instantie'].tolist()
values = grouped['value'].tolist()

combined_list = list(zip(groups, values))

years = [2020, 2021, 2022]

print(combined_list)
# Out:
# [('Centrale Raad van Beroep', 1008), ('College van Beroep voor het bedrijfsleven', 961), ('Gemeenschappelijk Hof van Justitie van Aruba, Curaçao, Sint Maarten en van Bonaire, Sint Eustatius en Saba',
:2020:2245', 'ECLI:NL:CRVB:2020:489', 'ECLI:NL:CRVB:2020:408', 'ECLI:NL:CRVB:2020:3190', 'ECLI:NL:CRVB:2020:1627', 'ECLI:NL:CRVB:2020:3372', 'ECLI:NL:CRVB:2020:2143', 'ECLI:NL:CRVB:2020:2073', 'ECLI:NL:CRVB:2020:3496', 'ECLI:NL:CRVB:2020:3180', 'ECLI:NL:CRVB:2020:1760', 'ECLI:NL:CRVB:2020:2727 ...
# 10458

# %%
sample_set = combined[combined['ecli'].isin(sampled_entries).reset_index(drop=True)]
sample_set
# Out:
#                          ecli        date  \
# 23      ECLI:NL:CBB:2020:1024  2020-12-22
# 30      ECLI:NL:CBB:2020:1030  2020-12-22
# 31      ECLI:NL:CBB:2020:1031  2020-12-22
# 33      ECLI:NL:CBB:2020:1033  2020-12-21
# 39       ECLI:NL:CBB:2020:108  2020-02-25
# ...                       ...         ...
# 52444  ECLI:NL:RBZWB:2022:885  2022-02-22
# 52451  ECLI:NL:RBZWB:2022:909  2022-02-23
# 52463  ECLI:NL:RBZWB:2022:951  2022-02-25
# 52464  ECLI:NL:RBZWB:2022:953  2022-02-24
# 52465  ECLI:NL:RBZWB:2022:954  2022-02-25
#
#                                         inhoudsindicatie  \
# 23     \nRegeling fosfaatreductieplan 2017. Geen verg...
# 30     \n\nartikel 23, derde lid, van de Meststoffenw...
# 31     \n\nMeststoffenwet\nAppellant is er niet in ge...
# 33     \nBeslissing ogv art 8:29 Awb. Beperking kenni...
# 39     \nAwb 6:7, 6:8 en 6:11 Bezwaar niet-ontvankeli...
# ...                                                  ...
# 52444  \nBeëindigen bijstandsuitkering o.g.v. de part...
# 52451                                            \nWIA\n
# 52463                                            \nBBZ\n
# 52464  \n\nCompensatie transitievergoeding. \nOp mome...
# 52465                                             \nWW\n
#
#                                        instantie  \
# 23     College van Beroep voor het bedrijfsleven
# 30     College van Beroep voor het bedrijfsleven
# 31     College van Beroep voor het bedrijfsleven
# 33     College van Beroep voor het bedrijfsleven
# 39     College van Beroep voor het bedrijfsleven
# ...                                          ...
# 52444             Rechtbank Zeeland-West-Brabant
# 52451             Rechtbank Zeeland-West-Brabant
# 52463             Rechtbank Zeeland-West-Brabant
# 52464             Rechtbank Zeeland-West-Brabant
# 52465             Rechtbank Zeeland-West-Brabant
#
#                                 rechtsgebied  \
# 23                             Bestuursrecht
# 30                             Bestuursrecht
# 31                             Bestuursrecht
# 33                             Bestuursrecht
# 39                             Bestuursrecht
# ...                                      ...
# 52444  Bestuursrecht; Socialezekerheidsrecht
# 52451                          Bestuursrecht
# 52463                          Bestuursrecht
# 52464                          Bestuursrecht
# 52465                          Bestuursrecht
#
#                           wetsverwijzing  \
# 23     Regeling fosfaatreductieplan 2017
# 30                        Meststoffenwet
# 31                        Meststoffenwet
# 33       Algemene wet bestuursrecht 8:29
# 39                                   NaN
# ...                                  ...
# 52444                                NaN
# 52451                                NaN
# 52463                                NaN
# 52464                                NaN
# 52465                                NaN
#
#                                            procesverloop  \
# 23     \nProcesverloop \n\n\nBij besluiten van 2 dece...
# 30     \nProcesverloop \n\n\nBij besluit van 3 januar...
# 31     \nProcesverloop \n\n\nBij besluit van 10 janua...
# 33     \nProcesverloop \n\n\nAppellant heeft beroep i...
# 39     \nProcesverloop \n\n\nBij besluit van 18 mei 2...
# ...                                                  ...
# 52444  \nProcesverloop \nVerzoeker heeft bezwaar gema...
# 52451  \nProcesverloop \nEiseres heeft beroep ingeste...
# 52463  \nProcesverloop\nIn een besluit van 24 januari...
# 52464  \nProcesverloop\n\n\nIn het besluit van 15 dec...
# 52465  \nProcesverloop\n\n\nIn het besluit van 11 dec...
#
#                                             overwegingen  \
# 23     \nOverwegingen \n\n\nArtikel 8:75a, eerste lid...
# 30     \nOverwegingen \n\n\n\nRelevante bepalingen\n\...
# 31     \nOverwegingen \n\n\n\nRelevante bepalingen\n\...
# 33     \nOverwegingen \n\n1. Op grond van artikel 8:2...
# 39     \nOverwegingen \n\n\n1.1.\nBij het bestreden b...
# ...                                                  ...
# 52444  \nOverwegingen \n1. Verzoeker ontving een bijs...
# 52451  \nOverwegingen \n1.\tFeiten\n\n\nEiseres is we...
# 52463  \nOverwegingen1.Op grond van de stukken en de ...
# 52464  \nOverwegingen\n\n\n\nFeiten\n\n\n1. Bij eiser...
# 52465  \nOverwegingen\n\n1.\t\tFeiten en omstandighed...
#
#                                               beslissing    year
# 23     \nBeslissing\n\n\nHet College\n\n\n\n- wijst h...  2020.0
# 30     \nBeslissing\n\n\nHet College verklaart het be...  2020.0
# 31     \nBeslissing\n\n\nHet College verklaart het be...  2020.0
# 33     \nBeslissing\n\n\nHet College: \n\n\n\nbeslist...  2020.0
# 39     \nBeslissing\n\n\nHet College verklaart het be...  2020.0
# ...                                                  ...     ...
# 52444  \nBeslissing\n\n\nDe voorzieningenrechter wijs...  2022.0
# 52451  \nBeslissing\nDe rechtbank verklaart het beroe...  2022.0
# 52463  \nBeslissing\n\n\nDe rechtbank verklaart het b...  2022.0
# 52464  \nBeslissing\n\n\nDe rechtbank: \n\n\n\nverkla...  2022.0
# 52465  \nBeslissing\n\n\nDe rechtbank: \n\n\n\nverkla...  2022.0
#
# [10458 rows x 10 columns]

# %%
sample_set.to_csv("C:/Users/Chloe/Documents/MaastrichtLaw&Tech/Thesis/MscThesis/Dataset/Creation/subset.csv")

# %% [markdown]
# # Compare subset vs full set

# %%
# Group by 'year' and 'instantie', then count the occurrences
grouped_sample_set = sample_set.groupby(['year', 'instantie']).size().reset_index(name='value')

# %%
# Get unique years and instanties
years_sample_set = grouped_sample_set['year'].unique()
instanties_sample_set = grouped_sample_set['instantie'].unique()

# %%
# Create an empty dictionary to hold the base heights for each year
base_height_sample = {year_s: 0 for year_s in years_sample_set}

# Set the figure size
plt.figure(figsize=(10, 10))

# %%
# Loop through each 'instantie' and create the stacked bars
for instantie in instanties_sample_set:
    # Get the subset of data for this 'instantie'
    subset_sample = grouped_sample_set[grouped_sample_set['instantie'] == instantie]

    # Plot the bars for this 'instantie'
    plt.bar(
        subset_sample['year'],
        subset_sample['value'],
        bottom=[base_height_sample[year] for year in subset_sample['year']],
        label=instantie
    )

    # Update the base height for each year
    for i, row in subset_sample.iterrows():
        base_height_sample[row['year']] += row['value']

# %%
plt.savefig('Stats/stats_sample_20_22.png')
plt.close()

# %%
grouped_sample_set.to_csv("Stats/stats_sample_20_22.csv", index=False)
